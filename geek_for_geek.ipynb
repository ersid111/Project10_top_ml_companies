# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
from autoscraper import AutoScraper
Name=[]
info=[]
location=[]
Website=[]
len_loc=[]

url = "https://www.javatpoint.com/machine-learning"
page = requests.get(url, verify=False)
page_text =page.text

title = (re.findall('<a href="(.+?)>', page_text))
    # company_info = (re.findall('class="company_info__wrap tagline">(.+?)</p>', page_text))
    # company_location=(re.findall('<span class="locality">(.+?)</span>', page_text))
    # website=(re.findall('href=http*(.+?)>',page_text))


Name=Name+title
    # info=info+company_info
    # location=location+company_location
    # Website=Website+website
    # len_loc.append(len(company_location))
New_Name=[]
for i in range(len(Name)):
    if 'https://www.javatpoint.com/' not in Name[i]:
       New_Name.append('https://www.javatpoint.com/'+Name[i])
New_Name=New_Name[4:-5]
New_Name.pop(4)
New_Name
# Out:
# c:\Users\mordes\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.javatpoint.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ['https://www.javatpoint.com/machine-learning" class="selected"',
#  'https://www.javatpoint.com/dbms-tutorial"',
#  'https://www.javatpoint.com/java-tutorial"',
#  'https://www.javatpoint.com/blockchain-tutorial"',
#  'https://www.javatpoint.com/selenium-tutorial"',
#  'https://www.javatpoint.com/html-tutorial"',
#  'https://www.javatpoint.com/css-tutorial"',
#  'https://www.javatpoint.com/javascript-tutorial"',
#  'https://www.javatpoint.com/data-structure-tutorial"',
#  'https://www.javatpoint.com/jquery-tutorial"',
#  'https://www.javatpoint.com/examaccess"',
#  'https://www.javatpoint.com/corejava-interview-questions"',
# ...

# %%
Name=['https://www.geeksforgeeks.org/ml-machine-learning/',
 'https://www.geeksforgeeks.org/ml-introduction-data-machine-learning/',
 'https://www.geeksforgeeks.org/artificial-intelligence-an-introduction/',
 'https://www.geeksforgeeks.org/machine-learning-versus-artificial-intelligence/',
 'https://www.geeksforgeeks.org/difference-between-machine-learning-and-artificial-intelligence/',
 'https://www.geeksforgeeks.org/agents-artificial-intelligence/',
 'https://www.geeksforgeeks.org/10-basic-machine-learning-interview-questions/',
 'https://www.geeksforgeeks.org/ml-introduction-data-machine-learning/',
 'https://www.geeksforgeeks.org/ml-understanding-data-processing/',
 'https://www.geeksforgeeks.org/python-create-test-datasets-using-sklearn/',
 'https://www.geeksforgeeks.org/python-generate-test-datasets-for-machine-learning/',
 'https://www.geeksforgeeks.org/data-preprocessing-machine-learning-python/',
 'https://www.geeksforgeeks.org/data-cleansing-introduction/',
 'https://www.geeksforgeeks.org/ml-feature-scaling-part-1/',
 'https://www.geeksforgeeks.org/ml-feature-scaling-part-2/',
 'https://www.geeksforgeeks.org/ml-label-encoding-of-datasets-in-python/',
 'https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/',
 'https://www.geeksforgeeks.org/ml-handling-imbalanced-data-with-smote-and-near-miss-algorithm-in-python/',
 'https://www.geeksforgeeks.org/ml-dummy-variable-trap-in-regression-models/?ref=rp',
 'https://www.geeksforgeeks.org/getting-started-with-classification/',
 'https://www.geeksforgeeks.org/basic-concept-classification-data-mining/',
 'https://www.geeksforgeeks.org/types-of-regression-techniques/',
 'https://www.geeksforgeeks.org/ml-classification-vs-regression/',
 'https://www.geeksforgeeks.org/ml-types-learning-supervised-learning/',
 'https://www.geeksforgeeks.org/multiclass-classification-using-scikit-learn/',
 'https://www.geeksforgeeks.org/gradient-descent-algorithm-and-its-variants/',
 'https://www.geeksforgeeks.org/ml-stochastic-gradient-descent-sgd/',
 'https://www.geeksforgeeks.org/ml-mini-batch-gradient-descent-with-python/',
 'https://www.geeksforgeeks.org/optimization-techniques-for-gradient-descent/',
 'https://www.geeksforgeeks.org/ml-momentum-based-gradient-optimizer-introduction/',
 'https://www.geeksforgeeks.org/ml-linear-regression/',
 'https://www.geeksforgeeks.org/gradient-descent-in-linear-regression/',
 'https://www.geeksforgeeks.org/mathematical-explanation-for-linear-regression-working/',
 'https://www.geeksforgeeks.org/ml-normal-equation-in-linear-regression/',
 'https://www.geeksforgeeks.org/linear-regression-python-implementation/',
 'https://www.geeksforgeeks.org/simple-linear-regression-using-r/',
 'https://www.geeksforgeeks.org/univariate-linear-regression-in-python/',
 'https://www.geeksforgeeks.org/ml-multiple-linear-regression-using-python/',
 'https://www.geeksforgeeks.org/multiple-linear-regression-using-r/',
 'https://www.geeksforgeeks.org/ml-locally-weighted-linear-regression/',
 'https://www.geeksforgeeks.org/generalized-linear-models/',
 'https://www.geeksforgeeks.org/python-linear-regression-using-sklearn/',
 'https://www.geeksforgeeks.org/linear-regression-using-tensorflow/',
 'https://www.geeksforgeeks.org/a-practical-approach-to-simple-linear-regression-using-r/',
 'https://www.geeksforgeeks.org/linear-regression-using-pytorch/',
 'https://www.geeksforgeeks.org/pyspark-linear-regression-using-apache-mllib/',
 'https://www.geeksforgeeks.org/ml-boston-housing-kaggle-challenge-with-linear-regression/',
 'https://www.geeksforgeeks.org/python-implementation-of-polynomial-regression/',
 'https://www.geeksforgeeks.org/softmax-regression-using-tensorflow/',
 'https://www.geeksforgeeks.org/understanding-logistic-regression/',
 'https://www.geeksforgeeks.org/ml-why-logistic-regression-in-classification/',
 'https://www.geeksforgeeks.org/ml-cost-function-in-logistic-regression/',
 'https://www.geeksforgeeks.org/ml-logistic-regression-using-tensorflow/',
 'https://www.geeksforgeeks.org/naive-bayes-classifiers/',
 'https://www.geeksforgeeks.org/classifying-data-using-support-vector-machinessvms-in-python/',
 'https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/',
 'https://www.geeksforgeeks.org/classifying-data-using-support-vector-machinessvms-in-r/',
 'https://www.geeksforgeeks.org/ml-using-svm-to-perform-classification-on-a-non-linear-dataset/',
 'https://www.geeksforgeeks.org/decision-tree/',
 'https://www.geeksforgeeks.org/python-decision-tree-regression-using-sklearn/',
 'https://www.geeksforgeeks.org/decision-tree-introduction-example/',
 'https://www.geeksforgeeks.org/decision-tree-implementation-python/',
 'https://www.geeksforgeeks.org/decision-tree-in-software-engineering/',
 'https://www.geeksforgeeks.org/random-forest-regression-in-python/',
 'https://www.geeksforgeeks.org/ensemble-classifier-data-mining/',
 'https://www.geeksforgeeks.org/ml-voting-classifier-using-sklearn/',
 'https://www.geeksforgeeks.org/ml-bagging-classifier/',
 'https://www.geeksforgeeks.org/ml-types-learning-part-2/',
 'https://www.geeksforgeeks.org/supervised-unsupervised-learning/',
 'https://www.geeksforgeeks.org/clustering-in-machine-learning/',
 'https://www.geeksforgeeks.org/different-types-clustering-algorithm/',
 'https://www.geeksforgeeks.org/k-means-clustering-introduction/',
 'https://www.geeksforgeeks.org/elbow-method-for-optimal-value-of-k-in-kmeans/',
 'https://www.geeksforgeeks.org/ml-k-means-algorithm/',
 'https://www.geeksforgeeks.org/analysis-of-test-data-using-k-means-clustering-in-python/',
 'https://www.geeksforgeeks.org/ml-mini-batch-k-means-clustering-algorithm/',
 'https://www.geeksforgeeks.org/ml-mean-shift-clustering/',
 'https://www.geeksforgeeks.org/dbscan-clustering-in-ml-density-based-clustering/',
 'https://www.geeksforgeeks.org/implementing-dbscan-algorithm-using-sklearn/',
 'https://www.geeksforgeeks.org/ml-fuzzy-clustering/',
 'https://www.geeksforgeeks.org/ml-spectral-clustering/',
 'https://www.geeksforgeeks.org/ml-optics-clustering-explanation/',
 'https://www.geeksforgeeks.org/ml-optics-clustering-implementing-using-sklearn/',
 'https://www.geeksforgeeks.org/ml-hierarchical-clustering-agglomerative-and-divisive-clustering/',
 'https://www.geeksforgeeks.org/implementing-agglomerative-clustering-using-sklearn/',
 'https://www.geeksforgeeks.org/gaussian-mixture-model/',
 'https://www.geeksforgeeks.org/what-is-reinforcement-learning/',
 'https://www.geeksforgeeks.org/ml-reinforcement-learning-algorithm-python-implementation-using-q-learning/',
 'https://www.geeksforgeeks.org/introduction-to-thompson-sampling-reinforcement-learning/',
 'https://www.geeksforgeeks.org/genetic-algorithm-for-reinforcement-learning-python-implementation/',
 'https://www.geeksforgeeks.org/sarsa-reinforcement-learning/',
 'https://www.geeksforgeeks.org/q-learning-in-python/',
 'https://www.geeksforgeeks.org/dimensionality-reduction/',
 'https://www.geeksforgeeks.org/ml-introduction-to-kernel-pca/',
 'https://www.geeksforgeeks.org/ml-principal-component-analysispca/',
 'https://www.geeksforgeeks.org/principal-component-analysis-with-python/',
 'https://www.geeksforgeeks.org/eigenvector-computation-and-low-rank-approximations/',
 'https://www.geeksforgeeks.org/ml-linear-discriminant-analysis/',
 'https://www.geeksforgeeks.org/gaussian-discriminant-analysis/',
 'https://www.geeksforgeeks.org/ml-independent-component-analysis/',
 'https://www.geeksforgeeks.org/feature-mapping/',
 'https://www.geeksforgeeks.org/ml-extra-tree-classifier-for-feature-selection/',
 'https://www.geeksforgeeks.org/chi-square-test-for-feature-selection-mathematical-explanation/',
 'https://www.geeksforgeeks.org/ml-t-distributed-stochastic-neighbor-embedding-t-sne-algorithm/',
 'https://www.geeksforgeeks.org/python-how-and-where-to-apply-feature-scaling/',
 'https://www.geeksforgeeks.org/parameters-feature-selection/',
 'https://www.geeksforgeeks.org/underfitting-and-overfitting-in-machine-learning/',
 'https://www.geeksforgeeks.org/introduction-to-natural-language-processing/',
 'https://www.geeksforgeeks.org/text-preprocessing-in-python-set-1/',
 'https://www.geeksforgeeks.org/text-preprocessing-in-python-set-2/',
 'https://www.geeksforgeeks.org/removing-stop-words-nltk-python/',
 'https://www.geeksforgeeks.org/tokenize-text-using-nltk-python/',
 'https://www.geeksforgeeks.org/nlp-how-tokenizing-text-sentence-words-works/',
 'https://www.geeksforgeeks.org/introduction-to-stemming/',
 'https://www.geeksforgeeks.org/python-stemming-words-with-nltk/',
 'https://www.geeksforgeeks.org/python-lemmatization-with-nltk/',
 'https://www.geeksforgeeks.org/python-lemmatization-with-textblob/',
 'https://www.geeksforgeeks.org/get-synonymsantonyms-nltk-wordnet-python/',
 'https://www.geeksforgeeks.org/introduction-to-artificial-neutral-networks/',
 'https://www.geeksforgeeks.org/introduction-artificial-neural-network-set-2/',
 'https://www.geeksforgeeks.org/introduction-ann-artificial-neural-networks-set-3-hybrid-systems/',
 'https://www.geeksforgeeks.org/introduction-to-ann-set-4-network-architectures/',
 'https://www.geeksforgeeks.org/activation-functions-neural-networks/',
 'https://www.geeksforgeeks.org/implementing-ann-training-process-in-python/',
 'https://www.geeksforgeeks.org/single-neuron-neural-network-python/',
 'https://www.geeksforgeeks.org/introduction-convolution-neural-network/',
 'https://www.geeksforgeeks.org/cnn-introduction-to-pooling-layer/',
 'https://www.geeksforgeeks.org/cnn-introduction-to-padding/',
 'https://www.geeksforgeeks.org/types-of-padding-in-convolution-layer/',
 'https://www.geeksforgeeks.org/applying-convolutional-neural-network-on-mnist-dataset/',
 'https://www.geeksforgeeks.org/introduction-to-recurrent-neural-network/',
 'https://www.geeksforgeeks.org/recurrent-neural-networks-explanation/',
 'https://www.geeksforgeeks.org/seq2seq-model-in-machine-learning/',
 'https://www.geeksforgeeks.org/deep-learning-introduction-to-long-short-term-memory/',
 'https://www.geeksforgeeks.org/long-short-term-memory-networks-explanation/',
 'https://www.geeksforgeeks.org/gated-recurrent-unit-networks/',
 'https://www.geeksforgeeks.org/ml-text-generation-using-gated-recurrent-unit-networks/',
 'https://www.geeksforgeeks.org/generative-adversarial-network-gan/',
 'https://www.geeksforgeeks.org/generative-adversarial-networks-gans-an-introduction/',
 'https://www.geeksforgeeks.org/use-cases-of-generative-adversarial-networks/',
 'https://www.geeksforgeeks.org/building-a-generative-adversarial-network-using-keras/',
 'https://www.geeksforgeeks.org/modal-collapse-in-gans/',
 'https://www.geeksforgeeks.org/deep-q-learning/',
 'https://www.geeksforgeeks.org/implementing-deep-q-learning-using-tensorflow/',
 '"https://www.geeksforgeeks.org/deploy-a-machine-learning-model-using-streamlit-library/?ref=rp"',
 '"https://www.geeksforgeeks.org/deploying-ml-models-as-api-using-fastapi/?ref=rp"',
 'https://www.geeksforgeeks.org/ml-rainfall-prediction-using-linear-regression/',
 'https://www.geeksforgeeks.org/identifying-handwritten-digits-using-logistic-regression-pytorch/',
 'https://www.geeksforgeeks.org/ml-kaggle-breast-cancer-wisconsin-diagnosis-using-logistic-regression/',
 'https://www.geeksforgeeks.org/python-implementation-of-movie-recommender-system/',
 'https://www.geeksforgeeks.org/train-a-support-vector-machine-to-recognize-facial-features-in-c/',
 'https://www.geeksforgeeks.org/decision-trees-fake-coin-puzzle/',
 'https://www.geeksforgeeks.org/ml-credit-card-fraud-detection/',
 'https://www.geeksforgeeks.org/python-nlp-analysis-of-restaurant-reviews/',
 'https://www.geeksforgeeks.org/applying-multinomial-naive-bayes-to-nlp-problems/',
 'https://www.geeksforgeeks.org/image-compression-using-k-means-clustering/',
 'https://www.geeksforgeeks.org/avengers-endgame-and-deep-learning/',
 'https://www.geeksforgeeks.org/how-does-google-use-machine-learning/',
 'https://www.geeksforgeeks.org/how-does-nasa-use-machine-learning/',
 'https://www.geeksforgeeks.org/5-mind-blowing-ways-facebook-uses-machine-learning/',
 'https://www.geeksforgeeks.org/targeted-advertising-using-machine-learning/',
 'https://www.geeksforgeeks.org/how-machine-learning-is-used-by-famous-companies/',
 'https://www.geeksforgeeks.org/pattern-recognition-introduction/',
 'https://www.geeksforgeeks.org/calculate-efficiency-binary-classifier/',
 'https://www.geeksforgeeks.org/ml-logistic-regression-v-s-decision-tree-classification/',
 'https://www.geeksforgeeks.org/r-vs-python-datascience/',
 'https://www.geeksforgeeks.org/explanation-of-fundamental-functions-involved-in-a3c-algorithm/',
 'https://www.geeksforgeeks.org/differential-privacy-and-deep-learning/',
 'https://www.geeksforgeeks.org/artificial-intelligence-vs-machine-learning-vs-deep-learning/',
 'https://www.geeksforgeeks.org/introduction-to-multi-task-learningmtl-for-deep-learning/',
 'https://www.geeksforgeeks.org/top-10-algorithms-every-machine-learning-engineer-should-know/',
 'https://www.geeksforgeeks.org/azure-virtual-machine-for-machine-learning/',
 'https://www.geeksforgeeks.org/30-minutes-to-machine-learning/',
 'https://www.geeksforgeeks.org/what-is-automl-in-machine-learning/',
 'https://www.geeksforgeeks.org/confusion-matrix-machine-learning/']

# %%
import requests
from bs4 import BeautifulSoup
for k in range(1,2):#len(Name)
# Making a GET request
    r = requests.get(str(New_Name[k]),verify=False)

    soup = BeautifulSoup(r.text, 'html.parser')
    soup.prettify().encode('cp1252', errors='ignore')
    # soup.prettify().encode('cp03b8', errors='ignore')
    containt=""
    for data in soup.find_all(["div","p"]):
        containt = str(containt+data.get_text())+"\n"
        
    # containt = str(containt.encode('utf-8'))
    # containt = re.sub(r"[^a-zA-Z0-9 ]","",containt)
    file_name = "files\\file-"+str(k)+".txt"
    with open(file_name, 'w',encoding="utf-8") as file:
        file.write(str(containt))
            
    

    
    # 
    
    # for i in range(len(data)):
    #     
    

    #
# Out:
# c:\Users\mordes\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.javatpoint.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# import module
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

# link for extract html data
def getdata(url):
	r = requests.get(url,verify=False)
	return r.text

htmldata = getdata("https://en.wikipedia.org/wiki/ADALINE")
soup = BeautifulSoup(htmldata, 'html.parser')
soup.prettify().encode('cp1252', errors='ignore')
# soup.prettify().encode('cp03b8', errors='ignore')
for data in soup.find_all(["p"]):
   containt = str(containt+data.get_text())
   
containt = str(containt.encode('utf-8'))
containt = re.sub(r"[^a-zA-Z0-9 ]","",containt)
file_name = "files\\file-"+str(k)+".txt"
with open(file_name, 'w') as file:
    file.write(str(containt))
# Out:
# c:\Users\mordes\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'en.wikipedia.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
New_Name[1]
# Out:
# 'https://www.javatpoint.com/dbms-tutorial"'

# %%
Name[17]
# Out:
# 'https://www.geeksforgeeks.org/ml-handling-imbalanced-data-with-smote-and-near-miss-algorithm-in-python/'

# %%
data
# Out:
# ['Arthur Samuel, a pioneer in the field of artificial intelligence and computer gaming, coined the term &#8220;Machine Learning&#8221;. He defined machine learning as &#8211; a &#8220;Field of study that gives computers the capability to learn without being explicitly programmed&#8221;. In a very layman&#8217;s manner, Machine Learning(ML) can be explained as automating and improving the learning process of computers based on their experiences without being actually programmed i.e. without any human assistance. The process starts with feeding good quality data and then training our machines(computers) by building machine learning models using the data and different algorithms. The choice of algorithms depends on what type of data do we have and what kind of task we are trying to automate. &nbsp;&nbsp;Example: Training of students during exams. While preparing for the exams students don&#8217;t actually cram the subject but try to learn it with complete understanding. Before the exami
# ...
